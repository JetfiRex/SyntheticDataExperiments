# %%
# Colab was used for this notebook hence the library installs
# %%capture
# !pip install pycaret --quiet --upgrade
# !pip install dabl --quiet --upgrade
# !pip install shap --quiet --upgrade
# !pip install sdv  --quiet --upgrade
# !pip install sdv[ctgan] --quiet --upgrade
# !pip install baytune --quiet --upgrade
# !pip install optuna --quiet --upgrade
# Out:
# UsageError: Line magic function `%%capture` not found.

# %% [markdown]
# ## **Why this was done**
# 1. Learn about synthetic data generation and see if it can improve a model
# 2. Work with PyCaret on a classification problem
# 3. Work on an insurance related problem (although ficticious data)
# 4. Build a `streamlit` app
#
# ## **The data**
# HR data isn't easy to find given the nature of the data. However IBM has created [fictious data](https://www.kaggle.com/pavansubhasht/ibm-hr-analytics-attrition-dataset) around whether an employee left after 6 months which can be used. The features for each employee are...
#
# * ` age `
# * ` bmi `
# * ` children `
# * ` sex `
# * ` smoker `
# * ` region `

# %% [markdown]
# # **Libraries**

# %%
from pycaret.classification import * 
#from pycaret.regression import * # Preprocessing, modelling, interpretation, deployment...
from sklearn.impute import SimpleImputer
import pandas as pd # Basic data manipulation
#import dabl as db # Summary plot
from sklearn.model_selection import train_test_split # Data split
from sdv.tabular import CopulaGAN, GaussianCopula, CTGAN # Synthetic data
from sdv.evaluation import evaluate # Evaluate synthetic data
#from btb.tuning import Tunable, GCPTuner # CopulaGAN optimising
#from btb.tuning import hyperparams as hp  # Set hyperparameters for optimising
import joblib # Saving preparation steps
import sdv.constraints as cons # Evaluate synthetic data

# %% [markdown]
# # **Importing data**

# %%
# Read and output the top 5 rows
ins_data = pd.read_csv("insurance.csv")
ins_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
ins_data = pd.read_csv("insurance.csv")
from matplotlib import pyplot as plt
plt.hist(ins_data['charges'], bins=[1000*i for i in range (65)])
ins_data['charges'].describe()
def transform(x):
    if x<5000: return 0 # First"Peak"
    if x<16000: return 1 # Second Peak
    if x<31000: return 2 # Thrid Peak
    return 3
print(len(ins_data[ins_data["charges"]>31000]))
ins_data["charges"]=ins_data["charges"].map(transform)
# Out:
# 156

# %% [markdown]
# A fairly simply ordering per feature.
#
#
# Now feature(s) can be initialised
# * Target feature
# * Continuous features
# * Ordinal features
# * Categorical features
# * Features to ignore

# %%
# Target feature
target = "charges"

# Continuous/numeric features
cont_feats = ["age", "bmi"]

# Ordinal features
ord_feats = {"children" : ["0", "1", "2", "3", "4", "5"]}

# Categorical geatures
cat_feats = ["region", "smoker", "sex"]

# There is a value error for children:
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than.

# %%
# Split real data into training + test set
train, test, target_train, target_test = train_test_split(ins_data.drop("charges", axis = 1), ins_data["charges"], test_size = 0.4, random_state = 42)

# Add Attrition column back into training + test set
train["charges"] = target_train
test["charges"] = target_test

# %%
# Run pycaret setup
setup(data = train, 
      target = target, 
      test_data = test,
      numeric_features = cont_feats,
      categorical_features = cat_feats,
      ordinal_features = ord_feats,
      normalize_method = "zscore",
      ignore_low_variance = True,
      silent = True,
      verbose = False)
# Out:
# ([<pandas.io.formats.style.Styler at 0x27c08d57390>],
#         age        bmi  children  sex_female  smoker_no  region_northeast  \
#  25    59.0  27.719999       3.0         1.0        1.0               0.0
#  336   60.0  25.740000       0.0         0.0        1.0               0.0
#  47    28.0  34.770000       0.0         1.0        1.0               0.0
#  106   19.0  28.400000       1.0         1.0        1.0               0.0
#  1269  45.0  27.500000       3.0         0.0        1.0               0.0
#  ...    ...        ...       ...         ...        ...               ...
#  1095  18.0  31.350000       4.0         1.0        1.0               1.0
#  1130  39.0  23.870001       5.0         1.0        1.0               0.0
#  1294  58.0  25.174999       0.0         0.0        1.0               1.0
#  860   37.0  47.599998       2.0         1.0        0.0               0.0
#  1126  55.0  29.900000       0.0         0.0        1.0               0.0
#
#        region_northwest  region_southeast  region_southwest
#  25                 0.0               1.0               0.0
#  336                0.0               1.0               0.0
#  47                 1.0               0.0               0.0
#  106                0.0               0.0               1.0
#  1269               0.0               0.0               1.0
#  ...                ...               ...               ...
#  1095               0.0               0.0               0.0
#  1130               0.0               1.0               0.0
#  1294               0.0               0.0               0.0
#  860                0.0               0.0               1.0
#  1126               0.0               0.0               1.0
#
#  [802 rows x 9 columns],
#  10,
#  Pipeline(memory=None, steps=[('empty_step', 'passthrough')], verbose=False),
#        age     sex     bmi  children smoker     region  charges
#  25     59  female  27.720         3     no  southeast        1
#  336    60    male  25.740         0     no  southeast        1
#  47     28  female  34.770         0     no  northwest        0
#  106    19  female  28.400         1     no  southwest        0
#  1269   45    male  27.500         3     no  southwest        1
#  ...   ...     ...     ...       ...    ...        ...      ...
#  1095   18  female  31.350         4     no  northeast        0
#  1130   39  female  23.870         5     no  southeast        1
#  1294   58    male  25.175         0     no  northeast        1
#  860    37  female  47.600         2    yes  southwest        3
#  1126   55    male  29.900         0     no  southwest        1
#
#  [802 rows x 7 columns],
#         age        bmi  children  sex_female  smoker_no  region_northeast  \
#  25    59.0  27.719999       3.0         1.0        1.0               0.0
#  336   60.0  25.740000       0.0         0.0        1.0               0.0
#  47    28.0  34.770000       0.0         1.0        1.0               0.0
#  106   19.0  28.400000       1.0         1.0        1.0               0.0
#  1269  45.0  27.500000       3.0         0.0        1.0               0.0
#  ...    ...        ...       ...         ...        ...               ...
#  1095  18.0  31.350000       4.0         1.0        1.0               1.0
#  1130  39.0  23.870001       5.0         1.0        1.0               0.0
#  1294  58.0  25.174999       0.0         0.0        1.0               1.0
#  860   37.0  47.599998       2.0         1.0        0.0               0.0
#  1126  55.0  29.900000       0.0         0.0        1.0               0.0
#
#        region_northwest  region_southeast  region_southwest
#  25                 0.0               1.0               0.0
#  336                0.0               1.0               0.0
#  47                 1.0               0.0               0.0
#  106                0.0               0.0               1.0
#  1269               0.0               0.0               1.0
#  ...                ...               ...               ...
#  1095               0.0               0.0               0.0
#  1130               0.0               1.0               0.0
#  1294               0.0               0.0               0.0
#  860                0.0               0.0               1.0
#  1126               0.0               0.0               1.0
#
#  [802 rows x 9 columns],
#  'lightgbm',
#  {'parameter': 'Hyperparameters',
#   'auc': 'AUC',
#   'confusion_matrix': 'Confusion Matrix',
#   'threshold': 'Threshold',
#   'pr': 'Precision Recall',
#   'error': 'Prediction Error',
#   'class_report': 'Class Report',
#   'rfe': 'Feature Selection',
#   'learning': 'Learning Curve',
#   'manifold': 'Manifold Learning',
#   'calibration': 'Calibration Curve',
#   'vc': 'Validation Curve',
#   'dimension': 'Dimensions',
#   'feature': 'Feature Importance',
#   'feature_all': 'Feature Importance (All)',
#   'boundary': 'Decision Boundary',
#   'lift': 'Lift Chart',
#   'gain': 'Gain Chart',
#   'tree': 'Decision Tree'},
#  [],
#  {'lr': <pycaret.containers.models.classification.LogisticRegressionClassifierContainer at 0x27c08be42b0>,
#   'knn': <pycaret.containers.models.classification.KNeighborsClassifierContainer at 0x27c08be41d0>,
#   'nb': <pycaret.containers.models.classification.GaussianNBClassifierContainer at 0x27bf8eedc50>,
#   'dt': <pycaret.containers.models.classification.DecisionTreeClassifierContainer at 0x27c04286860>,
#   'svm': <pycaret.containers.models.classification.SGDClassifierContainer at 0x27bf91b4cf8>,
#   'rbfsvm': <pycaret.containers.models.classification.SVCClassifierContainer at 0x27bf9023780>,
#   'gpc': <pycaret.containers.models.classification.GaussianProcessClassifierContainer at 0x27bf9090898>,
#   'mlp': <pycaret.containers.models.classification.MLPClassifierContainer at 0x27c08bd2eb8>,
#   'ridge': <pycaret.containers.models.classification.RidgeClassifierContainer at 0x27c00209ba8>,
#   'rf': <pycaret.containers.models.classification.RandomForestClassifierContainer at 0x27c08c63710>,
#   'qda': <pycaret.containers.models.classification.QuadraticDiscriminantAnalysisContainer at 0x27c08c63940>,
#   'ada': <pycaret.containers.models.classification.AdaBoostClassifierContainer at 0x27c08c639b0>,
#   'gbc': <pycaret.containers.models.classification.GradientBoostingClassifierContainer at 0x27c0013ab00>,
#   'lda': <pycaret.containers.models.classification.LinearDiscriminantAnalysisContainer at 0x27c00159978>,
#   'et': <pycaret.containers.models.classification.ExtraTreesClassifierContainer at 0x27c08cda0b8>,
#   'lightgbm': <pycaret.containers.models.classification.LGBMClassifierContainer at 0x27c08cda320>},
#  'clf-default-name',
#  -1,
#  25      1
#  336     1
#  47      0
#  106     0
#  1269    1
#         ..
#  1095    0
#  1130    1
#  1294    1
#  860     3
#  1126    1
#  Name: charges, Length: 802, dtype: int64,
#  False,
#         age        bmi  children  sex_female  smoker_no  region_northeast  \
#  764   45.0  25.174999       2.0         1.0        1.0               1.0
#  887   36.0  30.020000       0.0         1.0        1.0               0.0
#  890   64.0  26.885000       0.0         1.0        0.0               0.0
#  1293  46.0  25.745001       3.0         0.0        1.0               0.0
#  259   19.0  31.920000       0.0         0.0        0.0               0.0
#  ...    ...        ...       ...         ...        ...               ...
#  588   61.0  35.910000       0.0         1.0        1.0               1.0
#  872   42.0  24.860001       0.0         0.0        1.0               0.0
#  914   33.0  24.605000       2.0         0.0        1.0               0.0
#  679   49.0  23.180000       2.0         1.0        1.0               0.0
#  256   56.0  33.630001       0.0         0.0        0.0               0.0
#
#        region_northwest  region_southeast  region_southwest
#  764                0.0               0.0               0.0
#  887                1.0               0.0               0.0
#  890                1.0               0.0               0.0
#  1293               1.0               0.0               0.0
#  259                1.0               0.0               0.0
#  ...                ...               ...               ...
#  588                0.0               0.0               0.0
#  872                0.0               1.0               0.0
#  914                1.0               0.0               0.0
#  679                1.0               0.0               0.0
#  256                1.0               0.0               0.0
#
#  [536 rows x 9 columns],
#  [],
#  'c05a',
#  None,
#  'lightgbm',
#  False,
#  False,
#  None,
#  {'USI',
#   'X',
#   'X_test',
#   'X_train',
#   '_all_metrics',
#   '_all_models',
#   '_all_models_internal',
#   '_available_plots',
#   '_gpu_n_jobs_param',
#   '_internal_pipeline',
#   '_ml_usecase',
#   'create_model_container',
#   'data_before_preprocess',
#   'display_container',
#   'exp_name_log',
#   'experiment__',
#   'fix_imbalance_method_param',
#   'fix_imbalance_param',
#   'fold_generator',
#   'fold_groups_param',
#   'fold_param',
#   'fold_shuffle_param',
#   'gpu_param',
#   'html_param',
#   'imputation_classifier',
#   'imputation_regressor',
#   'iterative_imputation_iters_param',
#   'log_plots_param',
#   'logging_param',
#   'master_model_container',
#   'n_jobs_param',
#   'prep_pipe',
#   'pycaret_globals',
#   'seed',
#   'stratify_param',
#   'target_param',
#   'transform_target_method_param',
#   'transform_target_param',
#   'y',
#   'y_test',
#   'y_train'},
#  25      1
#  336     1
#  47      0
#  106     0
#  1269    1
#         ..
#  1095    0
#  1130    1
#  1294    1
#  860     3
#  1126    1
#  Name: charges, Length: 802, dtype: int32,
#  {'acc': <pycaret.containers.metrics.classification.AccuracyMetricContainer at 0x27c08ce4c88>,
#   'auc': <pycaret.containers.metrics.classification.ROCAUCMetricContainer at 0x27c08ce4cf8>,
#   'recall': <pycaret.containers.metrics.classification.RecallMetricContainer at 0x27c08ce4d68>,
#   'precision': <pycaret.containers.metrics.classification.PrecisionMetricContainer at 0x27c08ce4e48>,
#   'f1': <pycaret.containers.metrics.classification.F1MetricContainer at 0x27c08ce4f28>,
#   'kappa': <pycaret.containers.metrics.classification.KappaMetricContainer at 0x27c08d57048>,
#   'mcc': <pycaret.containers.metrics.classification.MCCMetricContainer at 0x27c08d570b8>},
#  False,
#  <MLUsecase.CLASSIFICATION: 1>,
#  'box-cox',
#  False,
#  Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['region', 'smoker',
#                                                              'sex'],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['age', 'bmi'],
#                                        target='charges', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fil...
#                  ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                  ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                  ('cluster_all', 'passthrough'),
#                  ('dummy', Dummify(target='charges')),
#                  ('fix_perfect', Remove_100(target='charges')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough')],
#           verbose=False),
#  'charges',
#  True,
#  {'lr': <pycaret.containers.models.classification.LogisticRegressionClassifierContainer at 0x27c08cda710>,
#   'knn': <pycaret.containers.models.classification.KNeighborsClassifierContainer at 0x27c08cda7b8>,
#   'nb': <pycaret.containers.models.classification.GaussianNBClassifierContainer at 0x27c08cda898>,
#   'dt': <pycaret.containers.models.classification.DecisionTreeClassifierContainer at 0x27c08cda908>,
#   'svm': <pycaret.containers.models.classification.SGDClassifierContainer at 0x27c08cdaa90>,
#   'rbfsvm': <pycaret.containers.models.classification.SVCClassifierContainer at 0x27c08cdac88>,
#   'gpc': <pycaret.containers.models.classification.GaussianProcessClassifierContainer at 0x27c08cdad30>,
#   'mlp': <pycaret.containers.models.classification.MLPClassifierContainer at 0x27c00115da0>,
#   'ridge': <pycaret.containers.models.classification.RidgeClassifierContainer at 0x27c08cdadd8>,
#   'rf': <pycaret.containers.models.classification.RandomForestClassifierContainer at 0x27c08cdaeb8>,
#   'qda': <pycaret.containers.models.classification.QuadraticDiscriminantAnalysisContainer at 0x27c08ce4128>,
#   'ada': <pycaret.containers.models.classification.AdaBoostClassifierContainer at 0x27c08ce4198>,
#   'gbc': <pycaret.containers.models.classification.GradientBoostingClassifierContainer at 0x27c08ce4278>,
#   'lda': <pycaret.containers.models.classification.LinearDiscriminantAnalysisContainer at 0x27c08ce4470>,
#   'et': <pycaret.containers.models.classification.ExtraTreesClassifierContainer at 0x27c08ce4518>,
#   'lightgbm': <pycaret.containers.models.classification.LGBMClassifierContainer at 0x27c08ce47b8>,
#   'Bagging': <pycaret.containers.models.classification.BaggingClassifierContainer at 0x27c08ce4ac8>,
#   'Stacking': <pycaret.containers.models.classification.StackingClassifierContainer at 0x27c08ce4748>,
#   'Voting': <pycaret.containers.models.classification.VotingClassifierContainer at 0x27c08ce4be0>,
#   'CalibratedCV': <pycaret.containers.models.classification.CalibratedClassifierCVContainer at 0x27c08ce4c18>},
#  [('Setup Config',
#                                   Description                   Value
#    0                               session_id                    1075
#    1                                   Target                 charges
#    2                              Target Type              Multiclass
#    3                            Label Encoded  0: 0, 1: 1, 2: 2, 3: 3
#    4                            Original Data                (802, 7)
#    5                           Missing Values                   False
#    6                         Numeric Features                       2
#    7                     Categorical Features                       4
#    8                         Ordinal Features                    True
#    9                High Cardinality Features                   False
#    10                 High Cardinality Method                    None
#    11                   Transformed Train Set                (802, 9)
#    12                    Transformed Test Set                (536, 9)
#    13                      Shuffle Train-Test                    True
#    14                     Stratify Train-Test                   False
#    15                          Fold Generator         StratifiedKFold
#    16                             Fold Number                      10
#    17                                CPU Jobs                      -1
#    18                                 Use GPU                   False
#    19                          Log Experiment                   False
#    20                         Experiment Name        clf-default-name
#    21                                     USI                    c05a
#    22                         Imputation Type                  simple
#    23          Iterative Imputation Iteration                    None
#    24                         Numeric Imputer                    mean
#    25      Iterative Imputation Numeric Model                    None
#    26                     Categorical Imputer                constant
#    27  Iterative Imputation Categorical Model                    None
#    28           Unknown Categoricals Handling          least_frequent
#    29                               Normalize                   False
#    30                        Normalize Method                    None
#    31                          Transformation                   False
#    32                   Transformation Method                    None
#    33                                     PCA                   False
#    34                              PCA Method                    None
#    35                          PCA Components                    None
#    36                     Ignore Low Variance                    True
#    37                     Combine Rare Levels                   False
#    38                    Rare Level Threshold                    None
#    39                         Numeric Binning                   False
#    40                         Remove Outliers                   False
#    41                      Outliers Threshold                    None
#    42                Remove Multicollinearity                   False
#    43             Multicollinearity Threshold                    None
#    44                              Clustering                   False
#    45                    Clustering Iteration                    None
#    46                     Polynomial Features                   False
#    47                       Polynomial Degree                    None
#    48                    Trignometry Features                   False
#    49                    Polynomial Threshold                    None
#    50                          Group Features                   False
#    51                       Feature Selection                   False
#    52                Feature Selection Method                 classic
#    53            Features Selection Threshold                    None
#    54                     Feature Interaction                   False
#    55                           Feature Ratio                   False
#    56                   Interaction Threshold                    None
#    57                           Fix Imbalance                   False
#    58                    Fix Imbalance Method                   SMOTE),
#   ('X_training Set',
#           age        bmi  children  sex_female  smoker_no  region_northeast  \
#    25    59.0  27.719999       3.0         1.0        1.0               0.0
#    336   60.0  25.740000       0.0         0.0        1.0               0.0
#    47    28.0  34.770000       0.0         1.0        1.0               0.0
#    106   19.0  28.400000       1.0         1.0        1.0               0.0
#    1269  45.0  27.500000       3.0         0.0        1.0               0.0
#    ...    ...        ...       ...         ...        ...               ...
#    1095  18.0  31.350000       4.0         1.0        1.0               1.0
#    1130  39.0  23.870001       5.0         1.0        1.0               0.0
#    1294  58.0  25.174999       0.0         0.0        1.0               1.0
#    860   37.0  47.599998       2.0         1.0        0.0               0.0
#    1126  55.0  29.900000       0.0         0.0        1.0               0.0
#
#          region_northwest  region_southeast  region_southwest
#    25                 0.0               1.0               0.0
#    336                0.0               1.0               0.0
#    47                 1.0               0.0               0.0
#    106                0.0               0.0               1.0
#    1269               0.0               0.0               1.0
#    ...                ...               ...               ...
#    1095               0.0               0.0               0.0
#    1130               0.0               1.0               0.0
#    1294               0.0               0.0               0.0
#    860                0.0               0.0               1.0
#    1126               0.0               0.0               1.0
#
#    [802 rows x 9 columns]),
#   ('y_training Set',
#    25      1
#    336     1
#    47      0
#    106     0
#    1269    1
#           ..
#    1095    0
#    1130    1
#    1294    1
#    860     3
#    1126    1
#    Name: charges, Length: 802, dtype: int32),
#   ('X_test Set',
#           age        bmi  children  sex_female  smoker_no  region_northeast  \
#    764   45.0  25.174999       2.0         1.0        1.0               1.0
#    887   36.0  30.020000       0.0         1.0        1.0               0.0
#    890   64.0  26.885000       0.0         1.0        0.0               0.0
#    1293  46.0  25.745001       3.0         0.0        1.0               0.0
#    259   19.0  31.920000       0.0         0.0        0.0               0.0
#    ...    ...        ...       ...         ...        ...               ...
#    588   61.0  35.910000       0.0         1.0        1.0               1.0
#    872   42.0  24.860001       0.0         0.0        1.0               0.0
#    914   33.0  24.605000       2.0         0.0        1.0               0.0
#    679   49.0  23.180000       2.0         1.0        1.0               0.0
#    256   56.0  33.630001       0.0         0.0        0.0               0.0
#
#          region_northwest  region_southeast  region_southwest
#    764                0.0               0.0               0.0
#    887                1.0               0.0               0.0
#    890                1.0               0.0               0.0
#    1293               1.0               0.0               0.0
#    259                1.0               0.0               0.0
#    ...                ...               ...               ...
#    588                0.0               0.0               0.0
#    872                0.0               1.0               0.0
#    914                1.0               0.0               0.0
#    679                1.0               0.0               0.0
#    256                1.0               0.0               0.0
#
#    [536 rows x 9 columns]),
#   ('y_test Set',
#    764     1
#    887     1
#    890     2
#    1293    1
#    259     3
#           ..
#    588     1
#    872     1
#    914     1
#    679     1
#    256     3
#    Name: charges, Length: 536, dtype: int64),
#   ('Transformation Pipeline',
#    Pipeline(memory=None,
#             steps=[('dtypes',
#                     DataTypes_Auto_infer(categorical_features=['region', 'smoker',
#                                                                'sex'],
#                                          display_types=False, features_todrop=[],
#                                          id_columns=[],
#                                          ml_usecase='classification',
#                                          numerical_features=['age', 'bmi'],
#                                          target='charges', time_features=[])),
#                    ('imputer',
#                     Simple_Imputer(categorical_strategy='not_available',
#                                    fill_value_categorical=None,
#                                    fil...
#                    ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                    ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                    ('cluster_all', 'passthrough'),
#                    ('dummy', Dummify(target='charges')),
#                    ('fix_perfect', Remove_100(target='charges')),
#                    ('clean_names', Clean_Colum_Names()),
#                    ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                    ('dfs', 'passthrough'), ('pca', 'passthrough')],
#             verbose=False))],
#  764     1
#  887     1
#  890     2
#  1293    1
#  259     3
#         ..
#  588     1
#  872     1
#  914     1
#  679     1
#  256     3
#  Name: charges, Length: 536, dtype: int64,
#  False,
#  StratifiedKFold(n_splits=10, random_state=None, shuffle=False),
#  1075,
#  5,
#  False,
#  -1)

# %% [markdown]
# Now it's "setup", I like to use `compare_models` to get a rough idea as to which model(s) might be best for this particular use case. The particular metrics I'm looking at are `AUC`, `Precision` and `Recall`. `Recall` is most important as we want to make sure we are correctly identifying the **true negatives** i.e. those that might leave in 6 months. Cross validation is also used.

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_f7b1fb8c_b46e_11eb_ac11_1856801111d2 th {
#           text-align: left;
#     }#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col0,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row1_col0,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row1_col1,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row1_col2,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row1_col3,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row1_col4,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row1_col5,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row1_col6,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row1_col7,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row2_col0,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row2_col1,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row2_col2,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row2_col3,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row2_col4,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row2_col5,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row2_col6,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row2_col7,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row3_col0,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row3_col1,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row3_col2,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row3_col3,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row3_col4,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row3_col5,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row3_col6,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row3_col7,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row4_col0,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row4_col1,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row4_col2,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row4_col3,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row4_col4,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row4_col5,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row4_col6,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row4_col7,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row5_col0,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row5_col1,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row5_col2,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row5_col3,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row5_col4,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row5_col5,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row5_col6,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row5_col7,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row6_col0,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row6_col1,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row6_col2,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row6_col3,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row6_col4,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row6_col5,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row6_col6,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row6_col7,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row7_col0,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row7_col1,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row7_col2,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row7_col3,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row7_col4,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row7_col5,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row7_col6,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row7_col7,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row8_col0,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row8_col1,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row8_col2,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row8_col3,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row8_col4,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row8_col5,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row8_col6,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row8_col7,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row9_col0,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row9_col1,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row9_col2,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row9_col3,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row9_col4,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row9_col5,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row9_col6,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row9_col7,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row10_col0,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row10_col1,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row10_col2,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row10_col3,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row10_col4,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row10_col5,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row10_col6,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row10_col7,#T_f7b1fb8c_b46e_1 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col1,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col2,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col3,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col4,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col5,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col6,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col8,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row1_col8,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row2_col8,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row3_col8,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row4_col8,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row5_col8,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row7_col8,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row8_col8,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row9_col8,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row10_col8,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row11_col8,#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row12_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row6_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_f7b1fb8c_b46e_11eb_ac11_1856801111d2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f7b1fb8c_b46e_11eb_ac11_1856801111d2level0_row0" class="row_heading level0 row0" >rf</th>
#                         <td id="T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#                         <td id="T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col1" class="data row0 col1" >0.8790</td>
#                         <td id="T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col2" class="data row0 col2" >0.9368</td>
#                         <td id="T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col3" class="data row0 col3" >0.8444</td>
#                         <td id="T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col4" class="data row0 col4" >0.8803</td>
#                         <td id="T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col5" class="data row0 col5" >0.8739</td>
#                         <td id="T_f7b1fb8c_b46e_11eb_ac11_1856801111d2row0_col6" class="data row0 col6" >0.8171</td>
#                         <td id="T_f7b1fb8c_b46e_11eb_ac11_18568011
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=1075, verbose=0,
#                        warm_start=False)

# %% [markdown]
# So `Logistic Regression` is looking promising for `AUC` but `Recall` is not high, regardless I'll build a model on this. As shown below each fold's metrics are shown and the average from them.

# %%
rf = create_model("rf") # Create logistic regression model
# Out:
# <style  type="text/css" >
# #T_f96a7894_b46e_11eb_8ff5_1856801111d2row10_col0,#T_f96a7894_b46e_11eb_8ff5_1856801111d2row10_col1,#T_f96a7894_b46e_11eb_8ff5_1856801111d2row10_col2,#T_f96a7894_b46e_11eb_8ff5_1856801111d2row10_col3,#T_f96a7894_b46e_11eb_8ff5_1856801111d2row10_col4,#T_f96a7894_b46e_11eb_8ff5_1856801111d2row10_col5,#T_f96a7894_b46e_11eb_8ff5_1856801111d2row10_col6{
#             background:  yellow;
#         }</style><table id="T_f96a7894_b46e_11eb_8ff5_1856801111d2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f96a7894_b46e_11eb_8ff5_1856801111d2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row0_col0" class="data row0 col0" >0.9259</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row0_col1" class="data row0 col1" >0.9805</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row0_col2" class="data row0 col2" >0.9099</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row0_col3" class="data row0 col3" >0.9252</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row0_col4" class="data row0 col4" >0.9228</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row0_col5" class="data row0 col5" >0.8885</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row0_col6" class="data row0 col6" >0.8899</td>
#             </tr>
#             <tr>
#                         <th id="T_f96a7894_b46e_11eb_8ff5_1856801111d2level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row1_col0" class="data row1 col0" >0.8519</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row1_col1" class="data row1 col1" >0.9315</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row1_col2" class="data row1 col2" >0.8386</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row1_col3" class="data row1 col3" >0.8517</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row1_col4" class="data row1 col4" >0.8504</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row1_col5" class="data row1 col5" >0.7796</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row1_col6" class="data row1 col6" >0.7803</td>
#             </tr>
#             <tr>
#                         <th id="T_f96a7894_b46e_11eb_8ff5_1856801111d2level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row2_col0" class="data row2 col0" >0.8625</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row2_col1" class="data row2 col1" >0.9224</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row2_col2" class="data row2 col2" >0.8172</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row2_col3" class="data row2 col3" >0.8536</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row2_col4" class="data row2 col4" >0.8511</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row2_col5" class="data row2 col5" >0.7902</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row2_col6" class="data row2 col6" >0.7941</td>
#             </tr>
#             <tr>
#                         <th id="T_f96a7894_b46e_11eb_8ff5_1856801111d2level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row3_col0" class="data row3 col0" >0.8875</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row3_col1" class="data row3 col1" >0.9440</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row3_col2" class="data row3 col2" >0.8519</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row3_col3" class="data row3 col3" >0.8929</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row3_col4" class="data row3 col4" >0.8857</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row3_col5" class="data row3 col5" >0.8272</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row3_col6" class="data row3 col6" >0.8312</td>
#             </tr>
#             <tr>
#                         <th id="T_f96a7894_b46e_11eb_8ff5_1856801111d2level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row4_col0" class="data row4 col0" >0.8750</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row4_col1" class="data row4 col1" >0.9342</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row4_col2" class="data row4 col2" >0.8417</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row4_col3" class="data row4 col3" >0.8781</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row4_col4" class="data row4 col4" >0.8724</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row4_col5" class="data row4 col5" >0.8137</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row4_col6" class="data row4 col6" >0.8169</td>
#             </tr>
#             <tr>
#                         <th id="T_f96a7894_b46e_11eb_8ff5_1856801111d2level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row5_col0" class="data row5 col0" >0.9000</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row5_col1" class="data row5 col1" >0.9556</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row5_col2" class="data row5 col2" >0.8585</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row5_col3" class="data row5 col3" >0.9113</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row5_col4" class="data row5 col4" >0.8978</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row5_col5" class="data row5 col5" >0.8454</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row5_col6" class="data row5 col6" >0.8517</td>
#             </tr>
#             <tr>
#                         <th id="T_f96a7894_b46e_11eb_8ff5_1856801111d2level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row6_col0" class="data row6 col0" >0.8500</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row6_col1" class="data row6 col1" >0.8721</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row6_col2" class="data row6 col2" >0.8001</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row6_col3" class="data row6 col3" >0.8409</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row6_col4" class="data row6 col4" >0.8400</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row6_col5" class="data row6 col5" >0.7728</td>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row6_col6" class="data row6 col6" >0.7761</td>
#             </tr>
#             <tr>
#                         <th id="T_f96a7894_b46e_11eb_8ff5_1856801111d2level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f96a7894_b46e_11eb_8ff5_1856801111d2row7_co

# %% [markdown]
# Some hyperparameter tuning may help improve the model a bit so I'll use `tune_model` and focus on `AUC`. I'm using the `optuna` library and searching using `tpe` searching algorithm.
#
# Overall there doesn't seem like much improvement.

# %% [markdown]
# # **Generating synthetic data**
# # **NAIVE GENERATING**
# # **CTGAN**
# There's a useful library `sdev` [Synthetic Data Generation](https://github.com/sdv-dev/SDV) to generate synthetic tabular data. I've played around with it specifically the `CopulaGAN` model.
#
# The general idea is to provide a `primary key` and to then run the model for so many `epochs`. There are hyperparameters to tune
# * `epochs`
# * `batch_size`
# * `embedding_dim`
# * `gen_dim`
# * `dis_dim`
# * `l2scale` (omitted in this experiment)
#
#
#
# Rather than running a CopulaGAN without hyperparameters or guessing hyperparameters I've leveraged `BTB` [Bayesian Tuning and Bandits](https://github.com/MLBazaar/BTB) which is an optimisation library. To start I'll initialise the `GCPTuner` which is used to declare the hyperparameters to tune. Then the hyperparameters can be called using `propose` from BTB.

# %%
def MAXINT(a,b): return (abs(a-b)+(a+b))//2

def MAX(a,b): return (abs(a-b)+(a+b))/2

def MININT(a,b): return (-abs(a-b)+(a+b))//2

def MIN(a,b): return (-abs(a-b)+(a+b))/2

def over_18(data): return MAXINT(data["age"],18)

age_constraint = cons.ColumnFormula(column = 'age',
                                    formula = over_18,
                                    handling_strategy = 'reject_sampling')

def children_range(data): return MININT(MAXINT(data["children"],0),5)

children_constraint = cons.ColumnFormula(column = 'children',
                                         formula = children_range,
                                         handling_strategy = 'reject_sampling')

min_bmi = min(ins_data["bmi"])
max_bmi = max(ins_data["bmi"])
print(min_bmi,max_bmi)

def bmi_range(data): return MIN(MAX(data["bmi"],min_bmi),max_bmi)

bmi_constraint = cons.ColumnFormula(column = 'bmi',
                                    formula = bmi_range,
                                    handling_strategy = 'reject_sampling')

min_charges= min(ins_data["charges"])
max_charges = max(ins_data["charges"])
print(min_charges,max_charges)

def charges_range(data): return MIN(MAX(data["charges"],min_charges*0.8),max_charges*1.25)

charges_constraint = cons.ColumnFormula(column = 'charges',
                                    formula = charges_range,
                                    handling_strategy = 'reject_sampling')

def charges_range_truncated(data): return MIN(MAX(data["charges"],12000),max_charges*1.25)

charges_constraint_2 = cons.ColumnFormula(column = 'charges',
                                    formula = charges_range_truncated,
                                    handling_strategy = 'reject_sampling')
# Out:
# 15.96 53.13
# 0 3

# %%
import time
best_score = 0 # Keep track of best score
best_data = None
tracker = 0 # Keep track of how many loops have completed
flag = True
scores=[]

real = train # Filter to only those employees that left
ST=time.time()
## TRAINING LOOP START ##
for _ in range(30): # only 1 and do the test

    # Increment the tracker
    tracker += 1
  
    # Every 5 loops output the tracker -> 1 loop
    print(tracker)

    # Get the hyperparameters for this loop
    #proposal = tuner.propose(1)
  
    # Create the CopulaGAN -> GAussianCopu;a
    # NOTE - batch_size is multiplied by 10 as needs to be a factor of 10
    model = CTGAN(constraints = [age_constraint, children_constraint, bmi_constraint])
    
    
    # Fit the CTGAN
    model.fit(real)
    metadata = model.get_metadata()
    # Create 600 rows of data
    synth_data = model.sample(num_rows = 600)
  
    # Evaluate the synthetic data against the real data
    score = evaluate(synthetic_data = synth_data, real_data = real)
    scores.append(score)

    print(score)
    # If the new hyperparameters beat the best ones, store them along with the score
    if score > best_score or flag:
        flag = False
        best_data = synth_data
        #best_params = proposal
        best_score = score
  


## TRAINING LOOP END ##
ED=time.time()
print((ED-ST)/60,"minutes")
# Out:
# 1
# 0.5891410929724538
# 2
# 0.48158768497404353
# 3
# 0.506542464178791
# 4
# 0.5420949734173611
# 5
# 0.47036591054408877
# 6
# 0.4884557439585662
# 7
# 0.5922876897497953
# 8
# 0.6140528195193619
# 9
# 0.48625986307490837
# 10
# 0.547980356705342
# 11
# 0.5838001440720292
# 12
# 0.5275151970702004
# 13
# 0.4520621588155527
# 14
# 0.4882196402305126
# 15
# 0.5228671146066648
# 16
# 0.5852267473328516
# 17
# 0.6077055981635021
# 18
# 0.5358922503071034
# 19
# 0.5765645411803739
# 20
# 0.568747667645034
# 21
# 0.5398129934096891
# 22
# 0.494428557686275
# 23
# 0.6188450114872106
# 24
# 0.600472375625511
# 25
# 0.5617174101731017
# 26
# 0.5712116793607004
# 27
# 0.5518828365598382
# 28
# 0.5663670937740919
# 29
# 0.5575664516201633
# 30
# 0.48559210348660187
# 20.673219617207845 minutes

# %%
metadata
# Out:
# Table(name=None, field_names=['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'])

# %%
bmi=synth_data["bmi"]

# %%
bmi.describe()
# Out:
# count    600.000000
# mean      38.988105
# std        6.843401
# min       17.809471
# 25%       34.374475
# 50%       38.863432
# 75%       44.119144
# max       53.109870
# Name: bmi, dtype: float64

# %%
score = evaluate(synthetic_data = best_data, real_data = real, aggregate = False)
score
# Out:
#                     metric                                     name  \
# 0          BNLogLikelihood           BayesianNetwork Log Likelihood
# 1        LogisticDetection             LogisticRegression Detection
# 2             SVCDetection                            SVC Detection
# 11         GMLogLikelihood           GaussianMixture Log Likelihood
# 12                  CSTest                              Chi-Squared
# 13                  KSTest  Inverted Kolmogorov-Smirnov D statistic
# 14          KSTestExtended  Inverted Kolmogorov-Smirnov D statistic
# 27  ContinuousKLDivergence   Continuous Kullback–Leibler Divergence
# 28    DiscreteKLDivergence     Discrete Kullback–Leibler Divergence
#
#       raw_score  normalized_score  min_value  max_value      goal
# 0     -2.699678          0.067227       -inf        0.0  MAXIMIZE
# 1      0.835990          0.835990        0.0        1.0  MAXIMIZE
# 2      0.377869          0.377869        0.0        1.0  MAXIMIZE
# 11 -1114.261443          0.000000       -inf        inf  MAXIMIZE
# 12     0.932434          0.932434        0.0        1.0  MAXIMIZE
# 13     0.894417          0.894417        0.0        1.0  MAXIMIZE
# 14     0.917778          0.917778        0.0        1.0  MAXIMIZE
# 27     0.608706          0.608706        0.0        1.0  MAXIMIZE
# 28     0.979045          0.979045        0.0        1.0  MAXIMIZE

# %%
score['normalized_score'].mean()
# Out:
# 0.6237184804714013

# %%
score = evaluate(synthetic_data = best_data, real_data = real, aggregate = True)
score
# Out:
# 0.6234127441611431

# %%
print(max(scores))
print(min(scores))
# Out:
# 0.6188450114872106
# 0.4520621588155527

# %%
model.save('best_copula.pkl')

# %%
synth_data.to_csv("ins_synth_data_classifier_CTGANImb.csv", index = False)

# %% [markdown]
# So after 75 loops the overall score is 0.81 (this score is between 0 and 1) for 600 synthetic examples of Attrition = "Yes" so it's not too bad.
#
# ```
# Best score obtained:  0.8127129012858366
# Best parameters:  {'epochs': 208, 'batch_size': 42, 'embedding_dim': 10, 'gen': 54, 'dim_gen': 788}
# ```
#
# # **Setting up data for round 2**
# The real dataset can be split into 60:40 training/test. Once this has been split the synthetic data can be added to the training data. This in a way doesn't "waste" the real dataset in the training.

# %%
# Load synth data in
synth_data = pd.read_csv("ins_synth_data_classifier_CTGANImb.csv")

# Add the 600 synthetic rows of data to training data + remove dataset column
mixed = pd.concat([train, synth_data])

# %%
synth_data
# Out:
#      age     sex        bmi  children smoker     region  charges
# 0     58  female  42.952625         0    yes  southeast        1
# 1     29    male  41.783000         0     no  northeast        0
# 2     31  female  39.215343         0     no  southwest        0
# 3     58    male  35.963096         0    yes  southeast        0
# 4     37  female  33.308222         5     no  northwest        1
# ..   ...     ...        ...       ...    ...        ...      ...
# 595   30  female  41.744318         0     no  northeast        1
# 596   27    male  29.278372         0     no  southwest        1
# 597   34  female  44.528648         1     no  southeast        0
# 598   52  female  46.553473         0     no  southwest        1
# 599   34  female  35.893012         2     no  southeast        0
#
# [600 rows x 7 columns]

# %%
print("Training size (real):", train.shape)
print("Training size (fake + real):", mixed.shape)
print("Testing size (real:", test.shape)
# Out:
# Training size (real): (802, 7)
# Training size (fake + real): (1402, 7)
# Testing size (real: (536, 7)

# %%
ord_feats = {"children" : list("012345")}

# %%
from matplotlib import pyplot as plt
#num_bins = 20
#group = [1000*i for i in range(13,65)]
#plt.hist(synth_data["charges"], group)
total01=len(synth_data["charges"])
ans01=[]
for i in range(0,4):
    num=len(synth_data["charges"][synth_data["charges"]==i])
    ans01.append(num/total01)
ans01=np.array(ans01)
print("The ratio of the synthetic data of charge >14000 is %.4f"%sum(ans01[14:]))
plt.title("charge occurrances for synthetic data for CTGAN")
plt.xlabel("charges")
plt.ylabel("occurrances")
plt.hist(synth_data["charges"],bins=[i for i in range (5)])
# Out:
# The ratio of the synthetic data of charge >14000 is 0.0000
# (array([299., 200.,  85.,  16.]),
#  array([0, 1, 2, 3, 4]),
#  <a list of 4 Patch objects>)

# %%
#plt.hist(ins_data["charges"][ins_data["charges"]>13000], group)
total02=len(ins_data["charges"])
ans02 = []
for i in range(4):
    num=len(ins_data["charges"][ins_data["charges"]==i])
    ans02.append(num/total02)
ans02=np.array(ans02)
print("The ratio of the original data of charge >14000 is %.4f"%sum(ans02[14:]))
plt.title("charge occurrances for real data")
plt.xlabel("charges")
plt.ylabel("occurrances")
plt.hist(ins_data["charges"],bins=[i for i in range (5)])
# Out:
# The ratio of the original data of charge >14000 is 0.0000
# (array([359., 633., 190., 156.]),
#  array([0, 1, 2, 3, 4]),
#  <a list of 4 Patch objects>)

# %% [markdown]
# Now this data can be fed into a new `setup` but this time declaring `test_data` as the test data that was created earlier.
#
# So there is a combination of **synthetic and real data in the training set** but only real in the test data.

# %%
# Run pycaret setup w/synthetic data
setup(data = mixed, 
      target = target, 
      test_data = test,
      train_size = 0.7, 
      numeric_features = cont_feats,
      categorical_features = cat_feats,
      ordinal_features = ord_feats,
      normalize_method = "zscore",
      ignore_low_variance = True,
      silent = True, verbose = False)
# Out:
# ([<pandas.io.formats.style.Styler at 0x27c0c983d30>],
#         age        bmi  children  sex_female  smoker_no  region_northeast  \
#  25    59.0  27.719999       3.0         1.0        1.0               0.0
#  336   60.0  25.740000       0.0         0.0        1.0               0.0
#  47    28.0  34.770000       0.0         1.0        1.0               0.0
#  106   19.0  28.400000       1.0         1.0        1.0               0.0
#  1269  45.0  27.500000       3.0         0.0        1.0               0.0
#  ...    ...        ...       ...         ...        ...               ...
#  595   30.0  41.744320       0.0         1.0        1.0               1.0
#  596   27.0  29.278372       0.0         0.0        1.0               0.0
#  597   34.0  44.528648       1.0         1.0        1.0               0.0
#  598   52.0  46.553471       0.0         1.0        1.0               0.0
#  599   34.0  35.893013       2.0         1.0        1.0               0.0
#
#        region_northwest  region_southeast  region_southwest
#  25                 0.0               1.0               0.0
#  336                0.0               1.0               0.0
#  47                 1.0               0.0               0.0
#  106                0.0               0.0               1.0
#  1269               0.0               0.0               1.0
#  ...                ...               ...               ...
#  595                0.0               0.0               0.0
#  596                0.0               0.0               1.0
#  597                0.0               1.0               0.0
#  598                0.0               0.0               1.0
#  599                0.0               1.0               0.0
#
#  [1402 rows x 9 columns],
#  10,
#  Pipeline(memory=None, steps=[('empty_step', 'passthrough')], verbose=False),
#        age     sex        bmi  children smoker     region  charges
#  25     59  female  27.720000         3     no  southeast        1
#  336    60    male  25.740000         0     no  southeast        1
#  47     28  female  34.770000         0     no  northwest        0
#  106    19  female  28.400000         1     no  southwest        0
#  1269   45    male  27.500000         3     no  southwest        1
#  ...   ...     ...        ...       ...    ...        ...      ...
#  595    30  female  41.744318         0     no  northeast        1
#  596    27    male  29.278372         0     no  southwest        1
#  597    34  female  44.528648         1     no  southeast        0
#  598    52  female  46.553473         0     no  southwest        1
#  599    34  female  35.893012         2     no  southeast        0
#
#  [1402 rows x 7 columns],
#         age        bmi  children  sex_female  smoker_no  region_northeast  \
#  25    59.0  27.719999       3.0         1.0        1.0               0.0
#  336   60.0  25.740000       0.0         0.0        1.0               0.0
#  47    28.0  34.770000       0.0         1.0        1.0               0.0
#  106   19.0  28.400000       1.0         1.0        1.0               0.0
#  1269  45.0  27.500000       3.0         0.0        1.0               0.0
#  ...    ...        ...       ...         ...        ...               ...
#  595   30.0  41.744320       0.0         1.0        1.0               1.0
#  596   27.0  29.278372       0.0         0.0        1.0               0.0
#  597   34.0  44.528648       1.0         1.0        1.0               0.0
#  598   52.0  46.553471       0.0         1.0        1.0               0.0
#  599   34.0  35.893013       2.0         1.0        1.0               0.0
#
#        region_northwest  region_southeast  region_southwest
#  25                 0.0               1.0               0.0
#  336                0.0               1.0               0.0
#  47                 1.0               0.0               0.0
#  106                0.0               0.0               1.0
#  1269               0.0               0.0               1.0
#  ...                ...               ...               ...
#  595                0.0               0.0               0.0
#  596                0.0               0.0               1.0
#  597                0.0               1.0               0.0
#  598                0.0               0.0               1.0
#  599                0.0               1.0               0.0
#
#  [1402 rows x 9 columns],
#  'lightgbm',
#  {'parameter': 'Hyperparameters',
#   'auc': 'AUC',
#   'confusion_matrix': 'Confusion Matrix',
#   'threshold': 'Threshold',
#   'pr': 'Precision Recall',
#   'error': 'Prediction Error',
#   'class_report': 'Class Report',
#   'rfe': 'Feature Selection',
#   'learning': 'Learning Curve',
#   'manifold': 'Manifold Learning',
#   'calibration': 'Calibration Curve',
#   'vc': 'Validation Curve',
#   'dimension': 'Dimensions',
#   'feature': 'Feature Importance',
#   'feature_all': 'Feature Importance (All)',
#   'boundary': 'Decision Boundary',
#   'lift': 'Lift Chart',
#   'gain': 'Gain Chart',
#   'tree': 'Decision Tree'},
#  [],
#  {'lr': <pycaret.containers.models.classification.LogisticRegressionClassifierContainer at 0x27c0c90d390>,
#   'knn': <pycaret.containers.models.classification.KNeighborsClassifierContainer at 0x27c0c90d4a8>,
#   'nb': <pycaret.containers.models.classification.GaussianNBClassifierContainer at 0x27c0c90d8d0>,
#   'dt': <pycaret.containers.models.classification.DecisionTreeClassifierContainer at 0x27c0c90d198>,
#   'svm': <pycaret.containers.models.classification.SGDClassifierContainer at 0x27c0c90d0f0>,
#   'rbfsvm': <pycaret.containers.models.classification.SVCClassifierContainer at 0x27c0c90d470>,
#   'gpc': <pycaret.containers.models.classification.GaussianProcessClassifierContainer at 0x27c0c90dc88>,
#   'mlp': <pycaret.containers.models.classification.MLPClassifierContainer at 0x27c0c90df60>,
#   'ridge': <pycaret.containers.models.classification.RidgeClassifierContainer at 0x27c0c8e2a20>,
#   'rf': <pycaret.containers.models.classification.RandomForestClassifierContainer at 0x27c0c905748>,
#   'qda': <pycaret.containers.models.classification.QuadraticDiscriminantAnalysisContainer at 0x27c0c918978>,
#   'ada': <pycaret.containers.models.classification.AdaBoostClassifierContainer at 0x27c0c918a20>,
#   'gbc': <pycaret.containers.models.classification.GradientBoostingClassifierContainer at 0x27c0c98ef98>,
#   'lda': <pycaret.containers.models.classification.LinearDiscriminantAnalysisContainer at 0x27c0c98ebe0>,
#   'et': <pycaret.containers.models.classification.ExtraTreesClassifierContainer at 0x27c0c98ec18>,
#   'lightgbm': <pycaret.containers.models.classification.LGBMClassifierContainer at 0x27c0c98e940>},
#  'clf-default-name',
#  -1,
#  25      1
#  336     1
#  47      0
#  106     0
#  1269    1
#         ..
#  595     1
#  596     1
#  597     0
#  598     1
#  599     0
#  Name: charges, Length: 1402, dtype: int64,
#  False,
#         age        bmi  children  sex_female  smoker_no  region_northeast  \
#  764   45.0  25.174999       2.0         1.0        1.0               1.0
#  887   36.0  30.020000       0.0         1.0        1.0               0.0
#  890   64.0  26.885000       0.0         1.0        0.0               0.0
#  1293  46.0  25.745001       3.0         0.0        1.0               0.0
#  259   19.0  31.920000       0.0         0.0        0.0               0.0
#  ...    ...        ...       ...         ...        ...               ...
#  588   61.0  35.910000       0.0         1.0        1.0               1.0
#  872   42.0  24.860001       0.0         0.0        1.0               0.0
#  914   33.0  24.605000       2.0         0.0        1.0               0.0
#  679   49.0  23.180000       2.0         1.0        1.0               0.0
#  256   56.0  33.630001       0.0         0.0        0.0               0.0
#
#        region_northwest  region_southeast  region_southwest
#  764                0.0               0.0               0.0
#  887                1.0               0.0               0.0
#  890                1.0               0.0               0.0
#  1293               1.0               0.0               0.0
#  259                1.0               0.0               0.0
#  ...                ...               ...               ...
#  588                0.0               0.0               0.0
#  872                0.0               1.0               0.0
#  914                1.0               0.0               0.0
#  679                1.0               0.0               0.0
#  256                1.0               0.0               0.0
#
#  [536 rows x 9 columns],
#  [],
#  '7775',
#  None,
#  'lightgbm',
#  False,
#  False,
#  None,
#  {'USI',
#   'X',
#   'X_test',
#   'X_train',
#   '_all_metrics',
#   '_all_models',
#   '_all_models_internal',
#   '_available_plots',
#   '_gpu_n_jobs_param',
#   '_internal_pipeline',
#   '_ml_usecase',
#   'create_model_container',
#   'data_before_preprocess',
#   'display_container',
#   'exp_name_log',
#   'experiment__',
#   'fix_imbalance_method_param',
#   'fix_imbalance_param',
#   'fold_generator',
#   'fold_groups_param',
#   'fold_param',
#   'fold_shuffle_param',
#   'gpu_param',
#   'html_param',
#   'imputation_classifier',
#   'imputation_regressor',
#   'iterative_imputation_iters_param',
#   'log_plots_param',
#   'logging_param',
#   'master_model_container',
#   'n_jobs_param',
#   'prep_pipe',
#   'pycaret_globals',
#   'seed',
#   'stratify_param',
#   'target_param',
#   'transform_target_method_param',
#   'transform_target_param',
#   'y',
#   'y_test',
#   'y_train'},
#  25      1
#  336     1
#  47      0
#  106     0
#  1269    1
#         ..
#  595     1
#  596     1
#  597     0
#  598     1
#  599     0
#  Name: charges, Length: 1402, dtype: int32,
#  {'acc': <pycaret.containers.metrics.classification.AccuracyMetricContainer at 0x27c0c912f28>,
#   'auc': <pycaret.containers.metrics.classification.ROCAUCMetricContainer at 0x27c0c912748>,
#   'recall': <pycaret.containers.metrics.classification.RecallMetricContainer at 0x27c0c912668>,
#   'precision': <pycaret.containers.metrics.classification.PrecisionMetricContainer at 0x27c0c9125f8>,
#   'f1': <pycaret.containers.metrics.classification.F1MetricContainer at 0x27c0c9830f0>,
#   'kappa': <pycaret.containers.metrics.classification.KappaMetricContainer at 0x27c0c983748>,
#   'mcc': <pycaret.containers.metrics.classification.MCCMetricContainer at 0x27c0c983b70>},
#  False,
#  <MLUsecase.CLASSIFICATION: 1>,
#  'box-cox',
#  False,
#  Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['region', 'smoker',
#                                                              'sex'],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['age', 'bmi'],
#                                        target='charges', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fil...
#                  ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                  ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                  ('cluster_all', 'passthrough'),
#                  ('dummy', Dummify(target='charges')),
#                  ('fix_perfect', Remove_100(target='charges')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough')],
#           verbose=False),
#  'charges',
#  True,
#  {'lr': <pycaret.containers.models.classification.LogisticRegressionClassifierContainer at 0x27c0c98e550>,
#   'knn': <pycaret.containers.models.classification.KNeighborsClassifierContainer at 0x27c0c98e4a8>,
#   'nb': <pycaret.containers.models.classification.GaussianNBClassifierContainer at 0x27c0c98e3c8>,
#   'dt': <pycaret.containers.models.classification.DecisionTreeClassifierContainer at 0x27c0c98e358>,
#   'svm': <pycaret.containers.models.classification.SGDClassifierContainer at 0x27c0c98e1d0>,
#   'rbfsvm': <pycaret.containers.models.classification.SVCClassifierContainer at 0x27c0c98de48>,
#   'gpc': <pycaret.containers.models.classification.GaussianProcessClassifierContainer at 0x27c0c98def0>,
#   'mlp': <pycaret.containers.models.classification.MLPClassifierContainer at 0x27c0c98dd30>,
#   'ridge': <pycaret.containers.models.classification.RidgeClassifierContainer at 0x27c0c98db38>,
#   'rf': <pycaret.containers.models.classification.RandomForestClassifierContainer at 0x27c0c98da58>,
#   'qda': <pycaret.containers.models.classification.QuadraticDiscriminantAnalysisContainer at 0x27c0c98d828>,
#   'ada': <pycaret.containers.models.classification.AdaBoostClassifierContainer at 0x27c0c98d7b8>,
#   'gbc': <pycaret.containers.models.classification.GradientBoostingClassifierContainer at 0x27c0c98d6d8>,
#   'lda': <pycaret.containers.models.classification.LinearDiscriminantAnalysisContainer at 0x27c0c90d6a0>,
#   'et': <pycaret.containers.models.classification.ExtraTreesClassifierContainer at 0x27c0c98d5f8>,
#   'lightgbm': <pycaret.containers.models.classification.LGBMClassifierContainer at 0x27c0c98d358>,
#   'Bagging': <pycaret.containers.models.classification.BaggingClassifierContainer at 0x27c0c98d080>,
#   'Stacking': <pycaret.containers.models.classification.StackingClassifierContainer at 0x27c0c98d390>,
#   'Voting': <pycaret.containers.models.classification.VotingClassifierContainer at 0x27c0c912780>,
#   'CalibratedCV': <pycaret.containers.models.classification.CalibratedClassifierCVContainer at 0x27c0c912e10>},
#  [('Setup Config',
#                                   Description                   Value
#    0                               session_id                     750
#    1                                   Target                 charges
#    2                              Target Type              Multiclass
#    3                            Label Encoded  0: 0, 1: 1, 2: 2, 3: 3
#    4                            Original Data               (1402, 7)
#    5                           Missing Values                   False
#    6                         Numeric Features                       2
#    7                     Categorical Features                       4
#    8                         Ordinal Features                    True
#    9                High Cardinality Features                   False
#    10                 High Cardinality Method                    None
#    11                   Transformed Train Set               (1402, 9)
#    12                    Transformed Test Set                (536, 9)
#    13                      Shuffle Train-Test                    True
#    14                     Stratify Train-Test                   False
#    15                          Fold Generator         StratifiedKFold
#    16                             Fold Number                      10
#    17                                CPU Jobs                      -1
#    18                                 Use GPU                   False
#    19                          Log Experiment                   False
#    20                         Experiment Name        clf-default-name
#    21                                     USI                    7775
#    22                         Imputation Type                  simple
#    23          Iterative Imputation Iteration                    None
#    24                         Numeric Imputer                    mean
#    25      Iterative Imputation Numeric Model                    None
#    26                     Categorical Imputer                constant
#    27  Iterative Imputation Categorical Model                    None
#    28           Unknown Categoricals Handling          least_frequent
#    29                               Normalize                   False
#    30                        Normalize Method                    None
#    31                          Transformation                   False
#    32                   Transformation Method                    None
#    33                                     PCA                   False
#    34                              PCA Method                    None
#    35                          PCA Components                    None
#    36                     Ignore Low Variance                    True
#    37                     Combine Rare Levels                   False
#    38                    Rare Level Threshold                    None
#    39                         Numeric Binning                   False
#    40                         Remove Outliers                   False
#    41                      Outliers Threshold                    None
#    42                Remove Multicollinearity                   False
#    43             Multicollinearity Threshold                    None
#    44                              Clustering                   False
#    45                    Clustering Iteration                    None
#    46                     Polynomial Features                   False
#    47                       Polynomial Degree                    None
#    48                    Trignometry Features                   False
#    49                    Polynomial Threshold                    None
#    50                          Group Features                   False
#    51                       Feature Selection                   False
#    52                Feature Selection Method                 classic
#    53            Features Selection Threshold                    None
#    54                     Feature Interaction                   False
#    55                           Feature Ratio                   False
#    56                   Interaction Threshold                    None
#    57                           Fix Imbalance                   False
#    58                    Fix Imbalance Method                   SMOTE),
#   ('X_training Set',
#           age        bmi  children  sex_female  smoker_no  region_northeast  \
#    25    59.0  27.719999       3.0         1.0        1.0               0.0
#    336   60.0  25.740000       0.0         0.0        1.0               0.0
#    47    28.0  34.770000       0.0         1.0        1.0               0.0
#    106   19.0  28.400000       1.0         1.0        1.0               0.0
#    1269  45.0  27.500000       3.0         0.0        1.0               0.0
#    ...    ...        ...       ...         ...        ...               ...
#    595   30.0  41.744320       0.0         1.0        1.0               1.0
#    596   27.0  29.278372       0.0         0.0        1.0               0.0
#    597   34.0  44.528648       1.0         1.0        1.0               0.0
#    598   52.0  46.553471       0.0         1.0        1.0               0.0
#    599   34.0  35.893013       2.0         1.0        1.0               0.0
#
#          region_northwest  region_southeast  region_southwest
#    25                 0.0               1.0               0.0
#    336                0.0               1.0               0.0
#    47                 1.0               0.0               0.0
#    106                0.0               0.0               1.0
#    1269               0.0               0.0               1.0
#    ...                ...               ...               ...
#
td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row4_col5" class="data row4 col5" >0.5045</td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row4_col6" class="data row4 col6" >0.5148</td>
#             </tr>
#             <tr>
#                         <th id="T_f0d42e46_b471_11eb_aa30_1856801111d2level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row5_col0" class="data row5 col0" >0.5929</td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row5_col1" class="data row5 col1" >0.7965</td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row5_col2" class="data row5 col2" >0.5874</td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row5_col3" class="data row5 col3" >0.6014</td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row5_col4" class="data row5 col4" >0.5622</td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row5_col5" class="data row5 col5" >0.3735</td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row5_col6" class="data row5 col6" >0.4018</td>
#             </tr>
#             <tr>
#                         <th id="T_f0d42e46_b471_11eb_aa30_1856801111d2level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row6_col0" class="data row6 col0" >0.4786</td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row6_col1" class="data row6 col1" >0.6569</td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row6_col2" class="data row6 col2" >0.3703</td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row6_col3" class="data row6 col3" >0.4497</td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row6_col4" class="data row6 col4" >0.4421</td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row6_col5" class="data row6 col5" >0.1794</td>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row6_col6" class="data row6 col6" >0.1855</td>
#             </tr>
#             <tr>
#                         <th id="T_f0d42e46_b471_11eb_aa30_1856801111d2level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f0d42e46_b471_11eb_aa30_1856801111d2row7_co

# %% [markdown]
# # **SECOND TRIAL**, NORMALIZED, CTGAN

# %% [markdown]
# With the tuner ready it's as simple as creating a training loop and then calling the tuner within the loop and feeding the hyperparameters into the CopulaGAN.

# %%
best_score = 0 # Keep track of best score
# best_params=None
best_data = None
tracker = 0 # Keep track of how many loops have completed
flag = True
scores=[]

real = train # Filter to only those employees that left

import time
ST=time.time()

## TRAINING LOOP START ##
for _ in range(30): # only 1 and do the test

    # Increment the tracker
    tracker += 1
  
    # Every 5 loops output the tracker -> 1 loop
    print(tracker)



    # Record the hyperparameters and score      
    # proposal = tuner.propose(1)
  
    # NOTE - batch_size is multiplied by 10 as needs to be a factor of 10
    #model = GaussianCopula(constraints = [age_constraint, children_constraint, bmi_constraint, charges_constraint])
    model = CTGAN(constraints = [age_constraint, children_constraint, bmi_constraint])
    
    # Fit the CopulaGAN
    model.fit(real)
    # Create 600 rows of data
    synth_data = model.sample(num_rows = 5000)
  
    # Evaluate the synthetic data against the real data
    score = evaluate(synthetic_data = synth_data, real_data = real)
    scores.append(score)

    print(score)
    # If the new hyperparameters beat the best ones, store them along with the score
    if score > best_score or flag:
        flag = False
        best_data = synth_data
        best_distributions = model.get_metadata()
        # best_params = proposal
        best_score = score
  
    # Record the hyperparameters and score      
    # tuner.record(proposal, score)


## TRAINING LOOP END ##
ED=time.time()
print("time used: %.3f mins"%((ED-ST)/60))
# Out:
# 1
# 0.5792328872671137
# 2
# 0.5873268184406185
# 3
# 0.6079707022427736
# 4
# 0.4905169461020827
# 5
# 0.5125543093102318
# 6
# 0.5445614335303762
# 7
# 0.46761512942134786
# 8
# 0.5515962570804042
# 9
# 0.5523480829411771
# 10
# 0.5287135302874133
# 11
# 0.4907506634503121
# 12
# 0.5232659643235292
# 13
# 0.5959775790446048
# 14
# 0.4963825903499366
# 15
# 0.5787569866159795
# 16
# 0.5304964901435695
# 17
# 0.4904551813245137
# 18
# 0.5812988986954155
# 19
# 0.5167920597151479
# 20
# 0.5406411635047096
# 21
# 0.6117362151353549
# 22
# 0.5192410305183858
# 23
# 0.53327250081972
# 24
# 0.5381990007019635
# 25
# 0.5315160216127732
# 26
# 0.5285686551174873
# 27
# 0.5034532104351306
# 28
# 0.587426528522753
# 29
# 0.5532808722021479
# 30
# 0.6018829055279505
# time used: 20.454 mins

# %%
best_data
# Out:
#     age     sex        bmi  children smoker     region  charges
# 0    22    male  25.744452         1     no  northwest        1
# 3    27  female  30.009945         1     no  southeast        3
# 10   27    male  24.810451         1     no  southeast        0
# 14   52    male  19.070730         0     no  southwest        1
# 15   49    male  20.431605         3     no  southwest        1
# ..  ...     ...        ...       ...    ...        ...      ...
# 83   57    male  19.346933         1     no  southeast        0
# 87   25  female  30.720547         1     no  southeast        0
# 92   19    male  16.105866         3     no  northwest        1
# 95   57  female  25.586742         1     no  southeast        1
# 2    50    male  24.780202         0     no  northeast        1
#
# [5000 rows x 7 columns]

# %%
best_distributions
# Out:
# Table(name=None, field_names=['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'])

# %%
score = evaluate(synthetic_data = best_data, real_data = real, aggregate = False)
score
# Out:
#                     metric                                     name  \
# 0          BNLogLikelihood           BayesianNetwork Log Likelihood
# 1        LogisticDetection             LogisticRegression Detection
# 2             SVCDetection                            SVC Detection
# 11         GMLogLikelihood           GaussianMixture Log Likelihood
# 12                  CSTest                              Chi-Squared
# 13                  KSTest  Inverted Kolmogorov-Smirnov D statistic
# 14          KSTestExtended  Inverted Kolmogorov-Smirnov D statistic
# 27  ContinuousKLDivergence   Continuous Kullback–Leibler Divergence
# 28    DiscreteKLDivergence     Discrete Kullback–Leibler Divergence
#
#      raw_score  normalized_score  min_value  max_value      goal
# 0    -2.690110      6.787350e-02       -inf        0.0  MAXIMIZE
# 1     0.694400      6.944000e-01        0.0        1.0  MAXIMIZE
# 2     0.372814      3.728136e-01        0.0        1.0  MAXIMIZE
# 11 -636.820386     2.706577e-277       -inf        inf  MAXIMIZE
# 12    0.944998      9.449985e-01        0.0        1.0  MAXIMIZE
# 13    0.850512      8.505117e-01        0.0        1.0  MAXIMIZE
# 14    0.898495      8.984953e-01        0.0        1.0  MAXIMIZE
# 27    0.655691      6.556913e-01        0.0        1.0  MAXIMIZE
# 28    0.985227      9.852268e-01        0.0        1.0  MAXIMIZE

# %%
synth=[]
for i in range (4):
    orig_size=len(train[train["charges"]==i])
    synth_part=best_data[best_data["charges"]==i]
    generate=synth_part.sample(n=min(max(0,350-orig_size),len(synth_part)))
    print(len(generate))
    synth.append(generate)
synth=pd.concat(synth)
synth.sample(frac=1)
# Out:
# 139
# 0
# 228
# 261
#        age     sex        bmi  children smoker     region  charges
# 3797    18    male  35.563653         0    yes  southeast        0
# 10148   24  female  26.566755         0     no  northwest        3
# 1807    42  female  33.209366         1     no  northwest        0
# 188     26  female  37.458124         0     no  southeast        3
# 3907    54    male  23.955476         1     no  northwest        3
# ...    ...     ...        ...       ...    ...        ...      ...
# 2680    24  female  20.888019         0    yes  southwest        3
# 3077    27  female  36.336724         0     no  southeast        0
# 984     35    male  33.763344         0    yes  northwest        0
# 4148    41    male  19.122491         0     no  southwest        0
# 4838    18  female  23.761240         0    yes  southeast        2
#
# [628 rows x 7 columns]

# %%
score = evaluate(synthetic_data = synth, real_data = train, aggregate = True)
score
# Out:
# 0.5246636612483022

# %%
print('Best score obtained: ', best_score)
# Out:
# Best score obtained:  0.6117362151353549

# %%
print(max(scores))
print(min(scores))
# Out:
# 0.6117362151353549
# 0.46761512942134786

# %%
model.save('best_copula.pkl')

# %%
synth.to_csv("ins_synth_norm_CTGANImb.csv", index = False)

# %% [markdown]
# # **Setting up data for round 2**
# The real dataset can be split into 60:40 training/test. Once this has been split the synthetic data can be added to the training data. This in a way doesn't "waste" the real dataset in the training.

# %%
# Load synth data in
synth_data2 = pd.read_csv("ins_synth_norm_CTGANImb.csv")

# Add the 600 synthetic rows of data to training data + remove dataset column
mixed = pd.concat([train, synth_data2])

# %%
mixed
# Out:
#       age     sex        bmi  children smoker     region  charges
# 25     59  female  27.720000         3     no  southeast        1
# 336    60    male  25.740000         0     no  southeast        1
# 47     28  female  34.770000         0     no  northwest        0
# 106    19  female  28.400000         1     no  southwest        0
# 1269   45    male  27.500000         3     no  southwest        1
# ...   ...     ...        ...       ...    ...        ...      ...
# 623    36  female  39.928198         1    yes  southwest        3
# 624    21    male  20.760925         1    yes  northeast        3
# 625    32  female  32.117123         1    yes  northeast        3
# 626    67    male  30.617989         0     no  southeast        3
# 627    46  female  25.942479         0     no  southwest        3
#
# [1430 rows x 7 columns]

# %%
print("Training size (real):", train.shape)
print("Training size (fake + real):", mixed.shape)
print("Testing size (real:", test.shape)
# Out:
# Training size (real): (802, 7)
# Training size (fake + real): (1430, 7)
# Testing size (real: (536, 7)

# %% [markdown]
# Now this data can be fed into a new `setup` but this time declaring `test_data` as the test data that was created earlier.
#
# So there is a combination of **synthetic and real data in the training set** but only real in the test data.

# %%
# Run pycaret setup w/synthetic data
setup(data = mixed, 
      target = "charges", 
      test_data = test,
      train_size = 0.7, 
      numeric_features = cont_feats,
      categorical_features = cat_feats,
      ordinal_features = ord_feats,
      normalize_method = "zscore",
      ignore_low_variance = True,
      silent = True, verbose = False)
# Out:
# ([<pandas.io.formats.style.Styler at 0x27c13f84780>],
#         age        bmi  children  sex_female  smoker_yes  region_northeast  \
#  25    59.0  27.719999       3.0         1.0         0.0               0.0
#  336   60.0  25.740000       0.0         0.0         0.0               0.0
#  47    28.0  34.770000       0.0         1.0         0.0               0.0
#  106   19.0  28.400000       1.0         1.0         0.0               0.0
#  1269  45.0  27.500000       3.0         0.0         0.0               0.0
#  ...    ...        ...       ...         ...         ...               ...
#  623   36.0  39.928200       1.0         1.0         1.0               0.0
#  624   21.0  20.760925       1.0         0.0         1.0               1.0
#  625   32.0  32.117123       1.0         1.0         1.0               1.0
#  626   67.0  30.617989       0.0         0.0         0.0               0.0
#  627   46.0  25.942480       0.0         1.0         0.0               0.0
#
#        region_northwest  region_southeast  region_southwest
#  25                 0.0               1.0               0.0
#  336                0.0               1.0               0.0
#  47                 1.0               0.0               0.0
#  106                0.0               0.0               1.0
#  1269               0.0               0.0               1.0
#  ...                ...               ...               ...
#  623                0.0               0.0               1.0
#  624                0.0               0.0               0.0
#  625                0.0               0.0               0.0
#  626                0.0               1.0               0.0
#  627                0.0               0.0               1.0
#
#  [1430 rows x 9 columns],
#  10,
#  Pipeline(memory=None, steps=[('empty_step', 'passthrough')], verbose=False),
#        age     sex        bmi  children smoker     region  charges
#  25     59  female  27.720000         3     no  southeast        1
#  336    60    male  25.740000         0     no  southeast        1
#  47     28  female  34.770000         0     no  northwest        0
#  106    19  female  28.400000         1     no  southwest        0
#  1269   45    male  27.500000         3     no  southwest        1
#  ...   ...     ...        ...       ...    ...        ...      ...
#  623    36  female  39.928198         1    yes  southwest        3
#  624    21    male  20.760925         1    yes  northeast        3
#  625    32  female  32.117123         1    yes  northeast        3
#  626    67    male  30.617989         0     no  southeast        3
#  627    46  female  25.942479         0     no  southwest        3
#
#  [1430 rows x 7 columns],
#         age        bmi  children  sex_female  smoker_yes  region_northeast  \
#  25    59.0  27.719999       3.0         1.0         0.0               0.0
#  336   60.0  25.740000       0.0         0.0         0.0               0.0
#  47    28.0  34.770000       0.0         1.0         0.0               0.0
#  106   19.0  28.400000       1.0         1.0         0.0               0.0
#  1269  45.0  27.500000       3.0         0.0         0.0               0.0
#  ...    ...        ...       ...         ...         ...               ...
#  623   36.0  39.928200       1.0         1.0         1.0               0.0
#  624   21.0  20.760925       1.0         0.0         1.0               1.0
#  625   32.0  32.117123       1.0         1.0         1.0               1.0
#  626   67.0  30.617989       0.0         0.0         0.0               0.0
#  627   46.0  25.942480       0.0         1.0         0.0               0.0
#
#        region_northwest  region_southeast  region_southwest
#  25                 0.0               1.0               0.0
#  336                0.0               1.0               0.0
#  47                 1.0               0.0               0.0
#  106                0.0               0.0               1.0
#  1269               0.0               0.0               1.0
#  ...                ...               ...               ...
#  623                0.0               0.0               1.0
#  624                0.0               0.0               0.0
#  625                0.0               0.0               0.0
#  626                0.0               1.0               0.0
#  627                0.0               0.0               1.0
#
#  [1430 rows x 9 columns],
#  'lightgbm',
#  {'parameter': 'Hyperparameters',
#   'auc': 'AUC',
#   'confusion_matrix': 'Confusion Matrix',
#   'threshold': 'Threshold',
#   'pr': 'Precision Recall',
#   'error': 'Prediction Error',
#   'class_report': 'Class Report',
#   'rfe': 'Feature Selection',
#   'learning': 'Learning Curve',
#   'manifold': 'Manifold Learning',
#   'calibration': 'Calibration Curve',
#   'vc': 'Validation Curve',
#   'dimension': 'Dimensions',
#   'feature': 'Feature Importance',
#   'feature_all': 'Feature Importance (All)',
#   'boundary': 'Decision Boundary',
#   'lift': 'Lift Chart',
#   'gain': 'Gain Chart',
#   'tree': 'Decision Tree'},
#  [],
#  {'lr': <pycaret.containers.models.classification.LogisticRegressionClassifierContainer at 0x27c13f79cf8>,
#   'knn': <pycaret.containers.models.classification.KNeighborsClassifierContainer at 0x27c13f79128>,
#   'nb': <pycaret.containers.models.classification.GaussianNBClassifierContainer at 0x27c13f79a58>,
#   'dt': <pycaret.containers.models.classification.DecisionTreeClassifierContainer at 0x27c13f792b0>,
#   'svm': <pycaret.containers.models.classification.SGDClassifierContainer at 0x27c13f79748>,
#   'rbfsvm': <pycaret.containers.models.classification.SVCClassifierContainer at 0x27c0ca7d4a8>,
#   'gpc': <pycaret.containers.models.classification.GaussianProcessClassifierContainer at 0x27c0ca7df98>,
#   'mlp': <pycaret.containers.models.classification.MLPClassifierContainer at 0x27c0ca7d6d8>,
#   'ridge': <pycaret.containers.models.classification.RidgeClassifierContainer at 0x27c0ca7d630>,
#   'rf': <pycaret.containers.models.classification.RandomForestClassifierContainer at 0x27c0ca7dfd0>,
#   'qda': <pycaret.containers.models.classification.QuadraticDiscriminantAnalysisContainer at 0x27c0ca7d6a0>,
#   'ada': <pycaret.containers.models.classification.AdaBoostClassifierContainer at 0x27c0ca7d710>,
#   'gbc': <pycaret.containers.models.classification.GradientBoostingClassifierContainer at 0x27c0ca7d5c0>,
#   'lda': <pycaret.containers.models.classification.LinearDiscriminantAnalysisContainer at 0x27c13fa2b70>,
#   'et': <pycaret.containers.models.classification.ExtraTreesClassifierContainer at 0x27c13fa2630>,
#   'lightgbm': <pycaret.containers.models.classification.LGBMClassifierContainer at 0x27c140efb38>},
#  'clf-default-name',
#  -1,
#  25      1
#  336     1
#  47      0
#  106     0
#  1269    1
#         ..
#  623     3
#  624     3
#  625     3
#  626     3
#  627     3
#  Name: charges, Length: 1430, dtype: int64,
#  False,
#         age        bmi  children  sex_female  smoker_yes  region_northeast  \
#  764   45.0  25.174999       2.0         1.0         0.0               1.0
#  887   36.0  30.020000       0.0         1.0         0.0               0.0
#  890   64.0  26.885000       0.0         1.0         1.0               0.0
#  1293  46.0  25.745001       3.0         0.0         0.0               0.0
#  259   19.0  31.920000       0.0         0.0         1.0               0.0
#  ...    ...        ...       ...         ...         ...               ...
#  588   61.0  35.910000       0.0         1.0         0.0               1.0
#  872   42.0  24.860001       0.0         0.0         0.0               0.0
#  914   33.0  24.605000       2.0         0.0         0.0               0.0
#  679   49.0  23.180000       2.0         1.0         0.0               0.0
#  256   56.0  33.630001       0.0         0.0         1.0               0.0
#
#        region_northwest  region_southeast  region_southwest
#  764                0.0               0.0               0.0
#  887                1.0               0.0               0.0
#  890                1.0               0.0               0.0
#  1293               1.0               0.0               0.0
#  259                1.0               0.0               0.0
#  ...                ...               ...               ...
#  588                0.0               0.0               0.0
#  872                0.0               1.0               0.0
#  914                1.0               0.0               0.0
#  679                1.0               0.0               0.0
#  256                1.0               0.0               0.0
#
#  [536 rows x 9 columns],
#  [],
#  '96b1',
#  None,
#  'lightgbm',
#  False,
#  False,
#  None,
#  {'USI',
#   'X',
#   'X_test',
#   'X_train',
#   '_all_metrics',
#   '_all_models',
#   '_all_models_internal',
#   '_available_plots',
#   '_gpu_n_jobs_param',
#   '_internal_pipeline',
#   '_ml_usecase',
#   'create_model_container',
#   'data_before_preprocess',
#   'display_container',
#   'exp_name_log',
#   'experiment__',
#   'fix_imbalance_method_param',
#   'fix_imbalance_param',
#   'fold_generator',
#   'fold_groups_param',
#   'fold_param',
#   'fold_shuffle_param',
#   'gpu_param',
#   'html_param',
#   'imputation_classifier',
#   'imputation_regressor',
#   'iterative_imputation_iters_param',
#   'log_plots_param',
#   'logging_param',
#   'master_model_container',
#   'n_jobs_param',
#   'prep_pipe',
#   'pycaret_globals',
#   'seed',
#   'stratify_param',
#   'target_param',
#   'transform_target_method_param',
#   'transform_target_param',
#   'y',
#   'y_test',
#   'y_train'},
#  25      1
#  336     1
#  47      0
#  106     0
#  1269    1
#         ..
#  623     3
#  624     3
#  625     3
#  626     3
#  627     3
#  Name: charges, Length: 1430, dtype: int32,
#  {'acc': <pycaret.containers.metrics.classification.AccuracyMetricContainer at 0x27c13f84cf8>,
#   'auc': <pycaret.containers.metrics.classification.ROCAUCMetricContainer at 0x27c13f84cc0>,
#   'recall': <pycaret.containers.metrics.classification.RecallMetricContainer at 0x27c13f84c50>,
#   'precision': <pycaret.containers.metrics.classification.PrecisionMetricContainer at 0x27c13f84be0>,
#   'f1': <pycaret.containers.metrics.classification.F1MetricContainer at 0x27c13f84b70>,
#   'kappa': <pycaret.containers.metrics.classification.KappaMetricContainer at 0x27c13f84b00>,
#   'mcc': <pycaret.containers.metrics.classification.MCCMetricContainer at 0x27c13f84a90>},
#  False,
#  <MLUsecase.CLASSIFICATION: 1>,
#  'box-cox',
#  False,
#  Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['region', 'smoker',
#                                                              'sex'],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['age', 'bmi'],
#                                        target='charges', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fil...
#                  ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                  ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                  ('cluster_all', 'passthrough'),
#                  ('dummy', Dummify(target='charges')),
#                  ('fix_perfect', Remove_100(target='charges')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough')],
#           verbose=False),
#  'charges',
#  True,
#  {'lr': <pycaret.containers.models.classification.LogisticRegressionClassifierContainer at 0x27c13f79e48>,
#   'knn': <pycaret.containers.models.classification.KNeighborsClassifierContainer at 0x27c13fa2400>,
#   'nb': <pycaret.containers.models.classification.GaussianNBClassifierContainer at 0x27c13fa2e80>,
#   'dt': <pycaret.containers.models.classification.DecisionTreeClassifierContainer at 0x27c13fa2b38>,
#   'svm': <pycaret.containers.models.classification.SGDClassifierContainer at 0x27c13fa2a58>,
#   'rbfsvm': <pycaret.containers.models.classification.SVCClassifierContainer at 0x27c13f9f518>,
#   'gpc': <pycaret.containers.models.classification.GaussianProcessClassifierContainer at 0x27c13f9f940>,
#   'mlp': <pycaret.containers.models.classification.MLPClassifierContainer at 0x27c13f9f9b0>,
#   'ridge': <pycaret.containers.models.classification.RidgeClassifierContainer at 0x27c13f9fba8>,
#   'rf': <pycaret.containers.models.classification.RandomForestClassifierContainer at 0x27c13f9fc88>,
#   'qda': <pycaret.containers.models.classification.QuadraticDiscriminantAnalysisContainer at 0x27c13f9feb8>,
#   'ada': <pycaret.containers.models.classification.AdaBoostClassifierContainer at 0x27c13f9ff28>,
#   'gbc': <pycaret.containers.models.classification.GradientBoostingClassifierContainer at 0x27c13f9f898>,
#   'lda': <pycaret.containers.models.classification.LinearDiscriminantAnalysisContainer at 0x27c13f9f438>,
#   'et': <pycaret.containers.models.classification.ExtraTreesClassifierContainer at 0x27c13f9f390>,
#   'lightgbm': <pycaret.containers.models.classification.LGBMClassifierContainer at 0x27c13f9f5f8>,
#   'Bagging': <pycaret.containers.models.classification.BaggingClassifierContainer at 0x27c13f84e80>,
#   'Stacking': <pycaret.containers.models.classification.StackingClassifierContainer at 0x27c13f9f7b8>,
#   'Voting': <pycaret.containers.models.classification.VotingClassifierContainer at 0x27c13f84d68>,
#   'CalibratedCV': <pycaret.containers.models.classification.CalibratedClassifierCVContainer at 0x27c13f84d30>},
#  [('Setup Config',
#                                   Description                   Value
#    0                               session_id                    8486
#    1                                   Target                 charges
#    2                              Target Type              Multiclass
#    3                            Label Encoded  0: 0, 1: 1, 2: 2, 3: 3
#    4                            Original Data               (1430, 7)
#    5                           Missing Values                   False
#    6                         Numeric Features                       2
#    7                     Categorical Features                       4
#    8                         Ordinal Features                    True
#    9                High Cardinality Features                   False
#    10                 High Cardinality Method                    None
#    11                   Transformed Train Set               (1430, 9)
#    12                    Transformed Test Set                (536, 9)
#    13                      Shuffle Train-Test                    True
#    14                     Stratify Train-Test                   False
#    15                          Fold Generator         StratifiedKFold
#    16                             Fold Number                      10
#    17                                CPU Jobs                      -1
#    18                                 Use GPU                   False
#    19                          Log Experiment                   False
#    20                         Experiment Name        clf-default-name
#    21                                     USI                    96b1
#    22                         Imputation Type                  simple
#    23          Iterative Imputation Iteration                    None
#    24                         Numeric Imputer                    mean
#    25      Iterative Imputation Numeric Model                    None
#    26                     Categorical Imputer                constant
#    27  Iterative Imputation Categorical Model                    None
#    28           Unknown Categoricals Handling          least_frequent
#    29                               Normalize                   False
#    30                        Normalize Method                    None
#    31                          Transformation                   False
#    32                   Transformation Method                    None
#    33                                     PCA                   False
#    34                              PCA Method                    None
#    35                          PCA Components                    None
#    36                     Ignore Low Variance                    True
#    37                     Combine Rare Levels                   False
#    38                    Rare Level Threshold                    None
#    39                         Numeric Binning                   False
#    40                         Remove Outliers                   False
#    41                      Outliers Threshold                    None
#    42                Remove Multicollinearity                   False
#    43             Multicollinearity Threshold                    None
#    44                              Clustering                   False
#    45                    Clustering Iteration                    None
#    46                     Polynomial Features                   False
#    47                       Polynomial Degree                    None
#    48                    Trignometry Features                   False
#    49                    Polynomial Threshold                    None
#    50                          Group Features                   False
#    51                       Feature Selection                   False
#    52                Feature Selection Method                 classic
#    53            Features Selection Threshold                    None
#    54                     Feature Interaction                   False
#    55                           Feature Ratio                   False
#    56                   Interaction Threshold                    None
#    57                           Fix Imbalance                   False
#    58                    Fix Imbalance Method                   SMOTE),
#   ('X_training Set',
#           age        bmi  children  sex_female  smoker_yes  region_northeast  \
#    25    59.0  27.719999       3.0         1.0         0.0               0.0
#    336   60.0  25.740000       0.0         0.0         0.0               0.0
#    47    28.0  34.770000       0.0         1.0         0.0               0.0
#    106   19.0  28.400000       1.0         1.0         0.0               0.0
#    1269  45.0  27.500000       3.0         0.0         0.0               0.0
#    ...    ...        ...       ...         ...         ...               ...
#    623   36.0  39.928200       1.0         1.0         1.0               0.0
#    624   21.0  20.760925       1.0         0.0         1.0               1.0
#    625   32.0  32.117123       1.0         1.0         1.0               1.0
#    626   67.0  30.617989       0.0         0.0         0.0               0.0
#    627   46.0  25.942480       0.0         1.0         0.0               0.0
#
#          region_northwest  region_southeast  region_southwest
#    25                 0.0               1.0               0.0
#    336                0.0               1.0               0.0
#    47                 1.0               0.0               0.0
#    106                0.0               0.0               1.0
#    1269               0.0               0.0               1.0
#    ...                ...               ...               ...
#    623                0.0               0.0               1.0
#    624                0.0               0.0               0.0
#    625                0.0               0.0               0.0
#    626                0.0               1.0               0.0
#    627                0.0               0.0               1.0
#
#    [1430 rows x 9 columns]),
#   ('y_training Set',
#    25      1
#    336     1
#    47      0
#    106     0
#    1269    1
#           ..
#    623     3
#    624     3
#    625     3
#    626     3
#    627     3
#    Name: charges, Length: 1430, dtype: int32),
#   ('X_test Set',
#           age        bmi  children  sex_female  smoker_yes  region_northeast  \
#    764   45.0  25.174999       2.0         1.0         0.0               1.0
#    887   36.0  30.020000       0.0         1.0         0.0               0.0
#    890   64.0  26.885000       0.0         1.0         1.0               0.0
#    1293  46.0  25.745001       3.0         0.0         0.0               0.0
#    259   19.0  31.920000       0.0         0.0         1.0               0.0
#    ...    ...        ...       ...         ...         ...               ...
#    588   61.0  35.910000       0.0         1.0         0.0               1.0
#    872   42.0  24.860001       0.0         0.0         0.0               0.0
#    914   33.0  24.605000       2.0         0.0         0.0               0.0
#    679   49.0  23.180000       2.0         1.0         0.0               0.0
#    256   56.0  33.630001       0.0         0.0         1.0               0.0
#
#          region_northwest  region_southeast  region_southwest
#    764                0.0               0.0               0.0
#    887                1.0               0.0               0.0
#    890                1.0               0.0               0.0
#    1293               1.0               0.0               0.0
#    259                1.0               0.0               0.0
#    ...                ...               ...               ...
#    588                0.0               0.0               0.0
#    872                0.0               1.0               0.0
#    914                1.0               0.0               0.0
#    679                1.0               0.0               0.0
#    256                1.0               0.0               0.0
#
#    [536 rows x 9 columns]),
#   ('y_test Set',
#    764     1
#    887     1
#    890     2
#    1293    1
#    259     3
#           ..
#    588     1
#    872     1
#    914     1
#    679     1
#    256     3
#    Name: charges, Length: 536, dtype: int64),
#   ('Transformation Pipeline',
#    Pipeline(memory=None,
#             steps=[('dtypes',
#                     DataTypes_Auto_infer(categorical_features=['region', 'smoker',
#                                                                'sex'],
#                                          display_types=False, features_todrop=[],
#                                          id_columns=[],
#                                          ml_usecase='classification',
#                                          numerical_features=['age', 'bmi'],
#                                          target='charges', time_features=[])),
#                    ('imputer',
#                     Simple_Imputer(categorical_strategy='not_available',
#                                    fill_value_categorical=None,
#                                    fil...
#                    ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                    ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                    ('cluster_all', 'passthrough'),
#                    ('dummy', Dummify(target='charges')),
#                    ('fix_perfect', Remove_100(target='charges')),
#                    ('clean_names', Clean_Colum_Names()),
#                    ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                    ('dfs', 'passthrough'), ('pca', 'passthrough')],
#             verbose=False))],
#  764     1
#  887     1
#  890     2
#  1293    1
#  259     3
#         ..
#  588     1
#  872     1
#  914     1
#  679     1
#  256     3
#  Name: charges, Length: 536, dtype: int64,
#  False,
#  StratifiedKFold(n_splits=10, random_state=None, shuffle=False),
#  8486,
#  5,
#  False,
#  -1)

# %% [markdown]
# Now setup the `compare_models` can be checked again. Interestingly the `AUC`, `Recall` and `Precision` all went up considerably. `Recall` nearly doubled!

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T
1856801111d2row12_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_e007b136_b474_11eb_9703_1856801111d2row3_col8,#T_e007b136_b474_11eb_9703_1856801111d2row10_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_e007b136_b474_11eb_9703_1856801111d2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e007b136_b474_11eb_9703_1856801111d2level0_row0" class="row_heading level0 row0" >gbc</th>
#                         <td id="T_e007b136_b474_11eb_9703_1856801111d2row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_e007b136_b474_11eb_9703_1856801111d2row0_col1" class="data row0 col1" >0.5538</td>
#                         <td id="T_e007b136_b474_11eb_9703_1856801111d2row0_col2" class="data row0 col2" >0.7709</td>
#                         <td id="T_e007b136_b474_11eb_9703_1856801111d2row0_col3" class="data row0 col3" >0.5477</td>
#                         <td id="T_e007b136_b474_11eb_9703_1856801111d2row0_col4" class="data row0 col4" >0.5346</td>
#                         <td id="T_e007b136_b474_11eb_9703_1856801111d2row0_col5" class="data row0 col5" >0.5273</td>
#                         <td id="T_e007b136_b474_11eb_9703_1856801111d2row0_col6" class="data row0 col6" >0.4032</td>
#                         <td id="T_e007b136_b474_11eb_9703_185
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=8486, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %% [markdown]
# A gradient boosting classifier was decided upon.

# %% [markdown]
# # **Finalising the model**
# Now with the model trained and evaluated it needs to be **finalised**. This encorporates the test data into the model that will be used on unseen data.

# %% [markdown]
# # **SECOND TRIAL**, CTGAN, NORMALIZED, CF

# %% [markdown]
# With the tuner ready it's as simple as creating a training loop and then calling the tuner within the loop and feeding the hyperparameters into the CopulaGAN.

# %%
train
# Out:
#       age     sex     bmi  children smoker     region  charges
# 25     59  female  27.720         3     no  southeast        1
# 336    60    male  25.740         0     no  southeast        1
# 47     28  female  34.770         0     no  northwest        0
# 106    19  female  28.400         1     no  southwest        0
# 1269   45    male  27.500         3     no  southwest        1
# ...   ...     ...     ...       ...    ...        ...      ...
# 1095   18  female  31.350         4     no  northeast        0
# 1130   39  female  23.870         5     no  southeast        1
# 1294   58    male  25.175         0     no  northeast        1
# 860    37  female  47.600         2    yes  southwest        3
# 1126   55    male  29.900         0     no  southwest        1
#
# [802 rows x 7 columns]

# %%
best_score = 0 # Keep track of best score
# best_params=None
best_data = None
tracker = 0 # Keep track of how many loops have completed
flag = True
scores=[]

real = train # Filter to only those employees that left

import time
ST=time.time()

## TRAINING LOOP START ##
for _ in range(30): # only 1 and do the test

    # Increment the tracker
    tracker += 1
  
    # Every 5 loops output the tracker -> 1 loop
    print(tracker)



    # Record the hyperparameters and score      
    # proposal = tuner.propose(1)
  
    # NOTE - batch_size is multiplied by 10 as needs to be a factor of 10
    #model = GaussianCopula(constraints = [age_constraint, children_constraint, bmi_constraint, charges_constraint])
    model = CTGAN(constraints = [age_constraint, children_constraint, bmi_constraint],
                 field_transformers = {k:"categorical_fuzzy" for k in ["sex", "smoker", "region"]})
    
    # Fit the CopulaGAN
    model.fit(real)
    # Create 600 rows of data
    synth_data = model.sample(num_rows = 1500)
  
    # Evaluate the synthetic data against the real data
    score = evaluate(synthetic_data = synth_data, real_data = real)
    scores.append(score)

    print(score)
    # If the new hyperparameters beat the best ones, store them along with the score
    if score > best_score or flag:
        flag = False
        best_data = synth_data
        best_distributions = model.get_metadata()
        # best_params = proposal
        best_score = score
  
    # Record the hyperparameters and score      
    # tuner.record(proposal, score)


## TRAINING LOOP END ##
ED=time.time()
print("time used: %.3f mins"%((ED-ST)/60))
# Out:
# 1
# 0.5166155867221017
# 2
# 0.48477919496656985
# 3

# %%
best_data

# %%
best_distributions

# %%
best=best_data
best_data=best_data[~best_data.index.duplicated()]
num_bins = 20
plt.hist(best_data["charges"], [2000*i for i in range (33)])

# %%
score = evaluate(synthetic_data = best_data, real_data = real, aggregate = False)
score

# %%
synth=[]
for i in range (6,32):
    orig_size=len(train[train["charges"]<(i+1)*2000][train["charges"]>(i)*2000])
    synth_part=best_data[best_data["charges"]<(i+1)*2000][best_data["charges"]>(i)*2000]
    generate=synth_part[:100-orig_size]
    synth.append(generate)
synth=pd.concat(synth)
synth.sample(frac=1)

# %%
score = evaluate(synthetic_data = synth, real_data = train, aggregate = True)
score

# %%
print('Best score obtained: ', best_score)

# %%
print(max(scores))
print(min(scores))

# %%
model.save('best_copula.pkl')

# %%
synth.to_csv("ins_synth_dat_univariate.csv", index = False)

# %% [markdown]
# # **Setting up data for round 2**
# The real dataset can be split into 60:40 training/test. Once this has been split the synthetic data can be added to the training data. This in a way doesn't "waste" the real dataset in the training.

# %%
# Load synth data in
synth_data2 = pd.read_csv("ins_synth_dat_univariate.csv")

# Add the 600 synthetic rows of data to training data + remove dataset column
mixed = pd.concat([train, synth_data2])

# %%
mixed

# %%
print("Training size (real):", train.shape)
print("Training size (fake + real):", mixed.shape)
print("Testing size (real:", test.shape)

# %%
#plt.hist(synth_data["charges"], group)
total=len(mixed["charges"])
plt.title("charge occurrances for synthetic data for univariate distribution")
plt.xlabel("charges")
plt.ylabel("occurrances")
plt.hist(mixed["charges"], [1000*i for i in range (65)])

# %%
#plt.hist(ins_data["charges"][ins_data["charges"]>13000], group)
total2=len(ins_data["charges"][ins_data["charges"]>13000])
ans2 = []
for i in range(14,65):
    num=len(ins_data["charges"][ins_data["charges"]<(i+1)*1000][ins_data["charges"]>=i*1000])
    ans2.append(num/total)
ans2=np.array(ans2)
plt.plot(range(14,65),ans2)
plt.show()

# %% [markdown]
# Now this data can be fed into a new `setup` but this time declaring `test_data` as the test data that was created earlier.
#
# So there is a combination of **synthetic and real data in the training set** but only real in the test data.

# %%
# Run pycaret setup w/synthetic data
setup(data = mixed, 
      target = "charges", 
      test_data = test,
      train_size = 0.7, 
      numeric_features = cont_feats,
      categorical_features = cat_feats,
      ordinal_features = ord_feats,
      normalize_method = "zscore",
      ignore_low_variance = True,
      silent = True, verbose = False)

# %% [markdown]
# Now setup the `compare_models` can be checked again. Interestingly the `AUC`, `Recall` and `Precision` all went up considerably. `Recall` nearly doubled!

# %%
compare_models()

# %% [markdown]
# A gradient boosting classifier was decided upon.

# %%
par = create_model("par")

# %%
final_gbc = finalize_model(huber)

# %% [markdown]
# **NOTE**: I haven't further explored the model e.g. feature importance as the purpose of this project was to focus on synthetic data generation and a streamlit app.

# %% [markdown]
# # **Saving and exporting ready for app build**
# To use the model in a `streamlit` app certain things need to be exported
# * The model
# * Preprocessed data
# * Preparation steps (`prep pipe`)

# %%
# Model (save)
save_model(final_gbc, "final_gbc")

# Preparation steps (get + save)
prep = get_config("prep_pipe")
joblib.dump(prep, 'prep_pipe.pkl', compress = 1)

# Preprocessed data (get + save)
get_config("X").to_csv("preprocssed_data.csv", index = False)

# %% [markdown]
# # **Streamlit app**
# The final output of this was a `streamlit` app to allow single predictions w/reason plots or multi predictions from an uploaded csv (see `README.md` and `app.py`).

# %% [markdown]
# # **Conclusion**
# I think that synthetic data generation can be a powerful tool especially in situations when further data collection cannot be performed in the near term. Fine tuning hyperparameters is great to have but more data and feature engineering are still superior.

# %%
# any random test
import random
# give a data of 20% 0-100, 40% 100-200, 30% 200-300,10% 300-400, 
small=[[100*random.random()] for _ in range (400)]
medium=[[100+100*random.random()] for _ in range (800)]
large=[[200+100*random.random()] for _ in range (600)]
extralarge=[[300+100*random.random()] for _ in range (200)]
mix=small+medium+large+extralarge
random.shuffle(mix)
df = pd.DataFrame(mix, columns=["s"])
final_ans=[]
for _ in range (200):
    toy_ans = list()
    model = GaussianCopula()
    model.fit(df)
    synth = model.sample(num_rows = 2000)
    for i in range(4):
        num=len(synth["s"][synth["s"]<(i+1)*100][synth["s"]>=i*100])
        toy_ans.append(num/2000)
    final_ans.append(toy_ans)
final_ans

# %%
plt.hist(np.array(mix),bins=np.array([10*i for i in range(41)]))

# %%
arr=np.array(final_ans)
trans_arr=np.transpose(arr)
plt.hist(trans_arr[3],bins=np.array([i/500 for i in range (38,55)]))

# %%
plt.hist(trans_arr[2],bins=np.array([i/500 for i in range (140,169)]))

# %%
plt.hist(trans_arr[1],bins=np.array([i/500 for i in range (179,207)]))

# %%
plt.hist(trans_arr[0],bins=np.array([i/500 for i in range (75,99)]))
